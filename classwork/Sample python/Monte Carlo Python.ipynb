# %%
import random

for i in range (0,50):
    value = random.uniform(-1, 1)
    print (value)
# Out:
# 0.40500171420699616
# -0.8131225500558319
# -0.3827995033789575
# -0.5636565258140214
# 0.10863704226226334
# -0.9220265153039073
# -0.9912431663821633
# -0.9855706554387835
# 0.6982746940409519
# 0.03442860100442191
# -0.772984065721589
# -0.03121134982279239
# 0.5133970389869309
# -0.3713535534572505
# -0.25812677709926657
# -0.4968373469870806
# 0.7492910590043065
# 0.8615471322855872
# 0.32819046202379254
# -0.5305245379264407
# 0.239915427175464
# 0.22482434651071093
# 0.6438198029667368
# -0.3844986350745583
# -0.9129929777255603
# 0.002175401907452912
# -0.16150803840403016
# 0.20765767837235427
# -0.4013276191008748
# 0.6849800835049862
# 0.7197633167724451
# -0.25231298088788345
# 0.23226368188553703
# -0.39848064500884783
# -0.4388252610306249
# 0.5237630376986837
# 0.39883350262060757
# 0.39857883151152773
# -0.36080461611929215
# -0.21596418552110896
# -0.6740151685429121
# -0.52344041980638
# 0.7222809586710999
# -0.29794309934178576
# 0.37378505686926045
# 0.07201444284279379
# -0.20211807975522134
# -0.7611758449065178
# -0.756468534543165
# 0.8654357516679507

# %%
import random

def montecarlo_pi(number_of_shots):
    for i in range(0, number_of_shots):
        x = random.uniform(-1,1)
        y = random.uniform(-1,1)
        
        if (x*x + y*y <1):
            counter = number_of_hits + 1
            
    return 4*number_of_hits/number_of_shots

# %%
montecarlo_pi(10000000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7eb72ed2cb13> in <module>
# ----> 1 montecarlo_pi(10000000)
#
# <ipython-input-10-7d8da94b9518> in montecarlo_pi(number_of_shots)
#       7
#       8         if (x*x + y*y <1):
# ----> 9             counter = number_of_hits + 1
#      10
#      11     return 4*number_of_hits/number_of_shots
#
# NameError: name 'number_of_hits' is not defined
