# %%
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
def matrix_mult(A, B):
    start = time.time()
    x = np.shape(A)[1]
    y = np.shape(A)[0]
    z = np.shape(B)[1]
    
    C = np.zeros((y, z))
    
    for i in range(y):
        for j in range(z):
            for k in range(x):
                C[i, j] += A[i,k] * B[k,j]
    
    end = time.time()
    elapsed_time = end - start
    
    return elapsed_time

# %%
def rand_matrix(size):
    x = size
    y = size
    A = np.zeros((x, y))
    B = np.zeros((x, y))
    
    for i in range(y):
        for j in range(x):
            A[i, j] = np.random.rand()
            B[i, j] = np.random.rand()
    
    return A, B

# %%
def compare_times(init_size, n):
    
    size = init_size*2**n
    A, B = rand_matrix(size)
    time_naive = matrix_mult(A, B)
    
    start = time.time()
    np.matmul(A,B)
    end = time.time()
    time_opt = end - start
    
    print(size,"x",size,"\n","Naive time:", time_naive, "\nOptimized time:", time_opt, "\n")
    
    return time_naive, time_opt

# %%
n = 8

time_naive = np.zeros(n)
time_opt = np.zeros(n)

for i in range(n):
    time_naive[i], time_opt[i] = compare_times(3, i)
# Out:
# 3 x 3
#  Naive time: 4.553794860839844e-05
# Optimized time: 9.34600830078125e-05
#
# 6 x 6
#  Naive time: 0.0002110004425048828
# Optimized time: 1.1444091796875e-05
#
# 12 x 12
#  Naive time: 0.0014874935150146484
# Optimized time: 1.2874603271484375e-05
#
# 24 x 24
#  Naive time: 0.013124465942382812
# Optimized time: 4.315376281738281e-05
#
# 48 x 48
#  Naive time: 0.09654617309570312
# Optimized time: 7.653236389160156e-05
#
# 96 x 96
#  Naive time: 0.7250020503997803
# Optimized time: 0.00035500526428222656
#
# 192 x 192
#  Naive time: 5.865478277206421
# Optimized time: 0.0007736682891845703
#
# 384 x 384
#  Naive time: 46.887245655059814
# Optimized time: 0.0034935474395751953

# %%
plt.figure()

exp = np.arange(n)
x = np.ones((n)) 
x = 3 * 2**exp

plt.scatter(x, time_naive)
plt.xlabel("NxN matrix")
plt.ylabel("Time to compute")
plt.title("Naive vs Optimized Algorithm")
plt.show()

# %%
plt.figure()

plt.scatter(x, time_opt)
plt.ylim(0, 0.005)
plt.xlabel("NxN matrix")
plt.ylabel("Time to compute")
plt.title("Optimized Algorithm")
plt.show()

# %%
#The naive algorithm has 3 nested loops which means it should be on O(N^3). It takes 8 times the work for doubling the input size.
#The optimized algorithm indicates that the Big O is logarithmic.
