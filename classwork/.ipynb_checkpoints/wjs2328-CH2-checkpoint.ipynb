# %%
def convert(baseTenNum):
    
    baseTwoNum = ''
    while baseTenNum > 0:
        digit = str(baseTenNum % 2)
        baseTenNum = baseTenNum // 2
        baseTwoNum = digit + baseTwoNum
    return baseTwoNum

n1 = convert(3000)
n2 = convert(600)

print(n1)
print(n2)
# Out:
# 101110111000
# 1001011000
